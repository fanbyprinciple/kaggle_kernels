# %% [markdown]
# <a href="https://www.kaggle.com/fanbyprinciple/cyrpto-world-heatmap?scriptVersionId=85280503" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
#%conda install matplotlib
#%conda install seaborn

# %% [markdown]
# # Heat map out of a tweet
#
# I found myself trying to see which is the hottest field in crypto based on this tweet from Crypto Ape founder Darren Lau:
#
# <blockquote class="twitter-tweet"><p lang="en" dir="ltr">Quick map of what&#39;s where at the moment in DeFi<br><br>Thanks frens for all the help and sorry if I didn&#39;t shill your bags 🙏 <a href="https://t.co/IXJmE9Ps9E">pic.twitter.com/IXJmE9Ps9E</a></p>&mdash; Darren Lau (Lau, Lau) 👘 (@Darrenlautf) <a href="https://twitter.com/Darrenlautf/status/1482003465627144195?ref_src=twsrc%5Etfw">January 14, 2022</a></blockquote> <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
#
# ![](https://pbs.twimg.com/media/FJEh1GwagAMgk-W?format=jpg&name=large)

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

platform = ["Etherium", "AVAX", "Fantom", "Aurora/Near",
              "Polygon", "Optimism", "Arbitrum", "Solana", 
                "Luna", "Atom"]
use = ["Wallets", "Liquidity markets", "Exchanges",
           "Dex Aggregators", "Staking", "Derivative", 
               "Perps/Leverage Trading", "Fund Management", "Options", 
                   "Structured Products", "Insurance", "Yield Farming",
                       "Fixed Interest Rate Protocols", "Bridges", "Gaming",
                           "Stablecoins", "NFT Exchange"]

harvest = np.array([[4, 3, 3, 3, 4, 3, 3, 3, 4, 2],
                    [3, 3, 3, 1, 1, 2, 5, 4, 3, 1],
                    [3, 4, 2, 2, 3, 3, 3, 5, 3, 2],
                    [3, 3, 2, 0, 1 ,2, 2, 1, 0, 0],
                    [4, 3, 1, 1, 1, 0, 1, 3, 2, 1],
                    [1, 2, 0, 1, 0, 2, 0, 1, 2, 3],
                    [3, 2, 0, 0, 1, 2, 1, 2, 1, 0],
                    [4, 0, 0, 0, 1, 3, 0, 3, 1, 0],
                    [1, 1, 0, 0, 1, 2, 3, 4, 3, 0],
                    [3, 2, 1, 1, 1, 0, 2, 3, 0, 0],
                    [1, 0, 0, 0, 1, 0, 0, 0, 1, 0],
                    [2, 3, 2, 0, 1, 0, 3, 4, 3, 0],
                    [3, 0, 0, 0, 0, 0, 1, 1, 0, 0],
                    [3, 4, 0, 3, 0, 4, 4, 2, 3, 0],
                    [0, 2, 1, 0, 4, 0, 0, 4, 2, 1],
                    [5, 3, 0, 0, 1, 0, 2, 1, 1, 0],
                    [5, 4, 2, 1, 1, 1, 1, 3, 4, 1]])

negative_harvest = harvest * -1

print(harvest.shape, negative_harvest.shape)
# Out:
# (17, 10) (17, 10)

# %%
fig, ax = plt.subplots()
im = ax.imshow(negative_harvest, cmap="plasma")
im = ax.imshow(harvest, cmap="YlOrRd")



fig.set_size_inches(18.5, 10.5)
fig.savefig('test2png.png', dpi=10)

# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(len(platform)), labels=platform)
ax.set_yticks(np.arange(len(use)), labels=use)
ax.xaxis.set_tick_params(labeltop=True, pad=40, top=True)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(use)):
    for j in range(len(platform)):
        text = ax.text(j, i, harvest[i, j],
                       ha="center", va="center", color="w")

ax.set_title("Activity heatmap of crypto world")
fig.tight_layout()
plt.show()

# %%
import seaborn as sns

# plotting the heatmap
hm = sns.heatmap(data = harvest)
  
# displaying the plotted heatmap
plt.show()
