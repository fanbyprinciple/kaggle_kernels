# %%
# loading the datasets
DATA_PATH = '../data/house_prices_advanced_regression_techniques'

import pandas as pd
import os

def load_housing_data(name):
    csv_path = os.path.join(DATA_PATH, name)
    return pd.read_csv(csv_path)

# %%
housing_train = load_housing_data("train.csv")
housing_test = load_housing_data("test.csv")
housing_sample_output = load_housing_data("sample_submission.csv")

# %%
housing_sample_output.head()
# Out:
#      Id      SalePrice
# 0  1461  169277.052498
# 1  1462  187758.393989
# 2  1463  183583.683570
# 3  1464  179317.477511
# 4  1465  150730.079977

# %%
housing_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
housing_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# getting the number of missing values per column
a = housing_train.isnull().sum()
print(a)
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
# missing values
housing_train.columns[housing_train.isnull().any()]
# Out:
# Index(['LotFrontage', 'Alley', 'MasVnrType', 'MasVnrArea', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Electrical', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence',
#        'MiscFeature'],
#       dtype='object')

# %%
housing_train.sample(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1304  1305         160       RM         32.0     3363   Pave   NaN      Reg
# 486    487          20       RL         79.0    10289   Pave   NaN      Reg
# 501    502          60       FV         75.0     9803   Pave   NaN      Reg
# 143    144          20       RL         78.0    10335   Pave   NaN      IR1
# 560    561          20       RL          NaN    11341   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 1304         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 486          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 501          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 143          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 560          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
datatypes = housing_train.dtypes
print(datatypes.unique())
# Out:
# [dtype('int64') dtype('O') dtype('float64')]

# %%
dropset = []
for i in housing_train.columns:
    if (housing_train[i].dtype == 'O'):
        dropset.append(i)

# %%
print(dropset)
# Out:
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

# %%
# dropping all the non numerical datset
housing_train_dropped = housing_train
for i in dropset:
    housing_train_dropped = housing_train_dropped.drop(i,axis=1)

# %%
datatypes = housing_train_dropped.dtypes

print(datatypes.unique())
# Out:
# [dtype('int64') dtype('float64')]

# %%
# dropping rows with NaN values

#housing_train_dropped = housing_train_dropped.dropna()

# filling with 0
housing_train_dropped = housing_train_dropped.fillna(0)

# %%
X = housing_train_dropped.drop("SalePrice", axis=1)

# %%
# seperating labels and features in housing_train
y = housing_train_dropped["SalePrice"]

# %%
y[:5]
# Out:
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %%
X[:5]
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  GarageArea  WoodDeckSF  \
# 0          2003       196.0         706  ...         548           0
# 1          1976         0.0         978  ...         460         298
# 2          2002       162.0         486  ...         608           0
# 3          1970         0.0         216  ...         642           0
# 4          2000       350.0         655  ...         836         192
#
#    OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# ...

# %%
from sklearn.svm import SVR

svm_reg = SVR(kernel="linear")
svm_reg.fit(X,y)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#     gamma='auto_deprecated', kernel='linear', max_iter=-1, shrinking=True,
#     tol=0.001, verbose=False)

# %%
# removing non integer columns

# dropping all the non numerical datset
housing_test_dropped = housing_test
for i in dropset:
    housing_test_dropped = housing_test_dropped.drop(i,axis=1)

# %%
housing_test_dropped.head()
# Out:
#      Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0  1461          20         80.0    11622            5            6
# 1  1462          20         81.0    14267            6            6
# 2  1463          60         74.0    13830            5            5
# 3  1464          60         78.0     9978            6            6
# 4  1465         120         43.0     5005            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  GarageArea  \
# 0       1961          1961         0.0       468.0  ...       730.0
# 1       1958          1958       108.0       923.0  ...       312.0
# 2       1997          1998         0.0       791.0  ...       482.0
# 3       1998          1998        20.0       602.0  ...       470.0
# 4       1992          1992         0.0       263.0  ...       506.0
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# ...

# %%
housing_test_dropped['Id']
# Out:
# 0       1461
# 1       1462
# 2       1463
# 3       1464
# 4       1465
#         ...
# 1454    2915
# 1455    2916
# 1456    2917
# 1457    2918
# 1458    2919
# Name: Id, Length: 1459, dtype: int64

# %%
# filling na with0
housing_test_dropped = housing_test_dropped.fillna(0)

# %%
predictions = svm_reg.predict(housing_test_dropped)

# %%
housing_sample_output.head()
# Out:
#      Id      SalePrice
# 0  1461  169277.052498
# 1  1462  187758.393989
# 2  1463  183583.683570
# 3  1464  179317.477511
# 4  1465  150730.079977

# %%
housing_sample_output.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 2 columns):
# Id           1459 non-null int64
# SalePrice    1459 non-null float64
# dtypes: float64(1), int64(1)
# memory usage: 22.9 KB

# %%
final  = pd.DataFrame({'Id': housing_test_dropped['Id'], 'SalePrice':predictions})

# %%
final.to_csv("first_submission_self.csv", index=False)
