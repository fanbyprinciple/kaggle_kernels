# %% [markdown]
# Taken from here: https://www.kaggle.com/kanncaa1/data-sciencetutorial-for-beginners

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/pokemon-challenge/combats.csv
# /kaggle/input/pokemon-challenge/pokemon.csv
# /kaggle/input/pokemon-challenge/tests.csv

# %%
data = pd.read_csv('/kaggle/input/pokemon-challenge/pokemon.csv')
data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
data.info()

# %%
data.corr()

# %%
data.columns

# %%
# creating a correlation matrix
import seaborn as snsbb
import matplotlib.pyplot as plt

f,ax = plt.subplots(figsize=(18,18))
sns.heatmap(data.corr(), annot=True, linewidths=.5, fmt='.1f', ax=ax)
plt.show()

# %%
data.head(10)

# %%
data.columns

# %%
data.Speed.plot(kind='line', color='g', label='Speed', linewidth=1, alpha=0.5,grid=True, linestyle=':')

# %%
data.plot(kind='scatter', x='Attack', y='Defense', alpha=0.5, color='red')

# %%
data.Speed.plot(kind='hist', bins=50)

# %%
data.plot(kind='hist', x='#',y='Attack', bins=50)

# %%
x = data['Defense'] > 200
data[x]

# %%
data[data['Attack']> 180]

# %%
# creating auser defined function
def tuple_ex():
    t = (1,2,3)
    return t
a,b,c = tuple_ex()
print(a,b,c)

# %%
# unsing of kwargs
# kwargs is a flexible argument that is also a dictionary

def f(**kwargs):
    for key, value in kwargs.items():
        print(key, " ", value)

f(country="sapna", capital="chaoudhary")

# %%
#lambda function is a faster way of writing a function

square = lambda x : x **2

print(square(4))

tot = lambda x,y,z: z + y* z
print(tot(1,2,3))

# %%
# map function
# takes in a series and applies it to all items on a list

number_list = [1,2,3]
y = map(lambda x:x**2, number_list)
print(list(y))

# %%
# iterators 
# an iterable is an object with an iter() method
# iterator produces next value with next() method

name = "ronaldo"
it = iter(name)
print(next(it)) # print nextiteration
print(*it) # print remaining iteration

# %%
# zip

list1 = [1,2,3,4]
list2 = [5,6,7,8]
z = zip(list1, list2)
print(z)
z_list = list(z)
print(z_list) # created a tuple using elements from botht the list

# %%
# unzipping

un_zip = zip(*z_list)
print(un_zip)

print(list(un_zip))

# %%
# list comprehendion
num1= [5,10,15]
num2 = [i**2 if i == 10 else i-5 if i < 7 else i + 5 for i in num1]
print(num2)

# %%
# classifying th epokemon on high and low speeds

threshold = sum(data.Speed)/len(data.Speed)
print(threshold)

data['speed_level'] = ["high" if i > threshold else "low" for i in data.Speed]

data.loc[:10, ["speed_level", "Speed"]]

# %%
data.columns

# %%
# looking at an tank pokemon

data[data['Defense']  > 150 ]
# Out:
#        #                  Name   Type 1   Type 2   HP  Attack  Defense  \
# 87    88          Mega Slowbro    Water  Psychic   95      75      180
# 98    99              Cloyster    Water      Ice   50      95      180
# 103  104                  Onix     Rock   Ground   35      45      160
# 223  224               Steelix    Steel   Ground   75      85      200
# 224  225          Mega Steelix    Steel   Ground   75     125      230
# 230  231               Shuckle      Bug     Rock   20      10      230
# 332  333                Aggron    Steel     Rock   70     110      180
# 333  334           Mega Aggron    Steel      NaN   70     140      230
# 414  415              Regirock     Rock      NaN   80     100      200
# 424  425        Primal Groudon   Ground     Fire  100     180      160
# 430  431  Deoxys Defense Forme  Psychic      NaN   50      70      160
# 456  457             Bastiodon     Rock    Steel   60      52      168
# ...

# %%
# cleaning the data

data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
data.tail()
# Out:
#        #            Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  796         Diancie     Rock  Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock  Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic  Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic   Dark  80     160       60      170
# 799  800       Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
data.shape
# Out:
# (800, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        799 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
# exploratory data analysis
# value_counts()
# Lets say value at 75% is Q3 and value at 25% is Q1.
# Outlier are smaller than Q1 - 1.5(Q3-Q1) and bigger than Q3 + 1.5(Q3-Q1). (Q3-Q1) = IQR 
# lower quartile is th emedian between median and lower value
# upper quartile is the median between media and upper value

print(data['Type 1'].value_counts(dropna=False))
# the nan values are also be counted
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ghost        32
# Ground       32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
data.describe()
# Out:
#               #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.0000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   400.5000   69.258750   79.001250   73.842500   72.820000   71.902500
# std    231.0844   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.0000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    200.7500   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    400.5000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    600.2500   80.000000  100.000000   90.000000   95.000000   90.000000
# max    800.0000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %%
print(data['Type 2'].value_counts(dropna=False))
# Out:
# NaN         386
# Flying       97
# Ground       35
# Poison       34
# Psychic      33
# Fighting     26
# Grass        25
# Fairy        23
# Steel        22
# Dark         20
# Dragon       18
# Ice          14
# Rock         14
# Ghost        14
# Water        14
# Fire         12
# Electric      6
# Normal        4
# Bug           3
# Name: Type 2, dtype: int64

# %%
data.describe()
# Out:
#               #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.0000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   400.5000   69.258750   79.001250   73.842500   72.820000   71.902500
# std    231.0844   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.0000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    200.7500   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    400.5000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    600.2500   80.000000  100.000000   90.000000   95.000000   90.000000
# max    800.0000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %%
# visual exploratiry data analysis

data.boxplot(column='Attack', by='Legendary')

# black line at top is max
# black line at bottom is min
# dots are outliers

# %%
# Tidying data

# melt()

data_new = data.head()
data_new
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
# lets melt 
# id_vars = what we dont want to melt
# value_vars what we want to melt
melted = pd.melt(frame=data_new, id_vars='Name', value_vars=['Attack', 'Defense'])
print(melted)
# Out:
#             Name variable  value
# 0      Bulbasaur   Attack     49
# 1        Ivysaur   Attack     62
# 2       Venusaur   Attack     82
# 3  Mega Venusaur   Attack    100
# 4     Charmander   Attack     52
# 5      Bulbasaur  Defense     49
# 6        Ivysaur  Defense     63
# 7       Venusaur  Defense     83
# 8  Mega Venusaur  Defense    123
# 9     Charmander  Defense     43

# %%
# pivoting data
# reverse of melting

melted.pivot(index = 'Name', columns = 'variable', values='value')
# Out:
# variable       Attack  Defense
# Name
# Bulbasaur          49       49
# Charmander         52       43
# Ivysaur            62       63
# Mega Venusaur     100      123
# Venusaur           82       83

# %%
#concatenating data

data1 = data.head()
data2 = data.tail()
conc_data_row = pd.concat([data1, data2], axis=0, ignore_index=True)
conc_data_row
# Out:
#      #            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0    1       Bulbasaur    Grass  Poison  45      49       49       65
# 1    2         Ivysaur    Grass  Poison  60      62       63       80
# 2    3        Venusaur    Grass  Poison  80      82       83      100
# 3    4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4    5      Charmander     Fire     NaN  39      52       43       60
# 5  796         Diancie     Rock   Fairy  50     100      150      100
# 6  797    Mega Diancie     Rock   Fairy  50     160      110      160
# 7  798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 8  799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 9  800       Volcanion     Fire   Water  80     110      120      130
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# ...

# %%
data1 = data['Attack'].head()
data2 = data['Defense'].head()
conc_data_col = pd.concat([data1, data2], axis=1)
# adds datafreme in columns
conc_data_col
# Out:
#    Attack  Defense
# 0      49       49
# 1      62       63
# 2      82       83
# 3     100      123
# 4      52       43

# %%
# data types
# we can make datagrame smaller through use of category

data.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
data['Type 1'] = data['Type 1'].astype('category')
data['Speed'] = data['Speed'].astype('float')

# %%
data.dtypes
# Out:
# #                int64
# Name            object
# Type 1        category
# Type 2          object
# HP               int64
# Attack           int64
# Defense          int64
# Sp. Atk          int64
# Sp. Def          int64
# Speed          float64
# Generation       int64
# Legendary         bool
# dtype: object

# %%
# things to do when dealing with missing  values
# leave it as it is
# drop them with dropna()
# fill missing values with fillna()
# fill missing values with test statistics like mean
# asset statement : check that you can turn on or turn off when you are done with your testing your program

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        799 non-null    object
#  2   Type 1      800 non-null    category
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    float64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), category(1), float64(1), int64(7), object(2)
# memory usage: 65.0+ KB

# %%
# lets check type 2
data["Type 2"].value_counts(dropna=False)
# there are 386 NaN values
# Out:
# NaN         386
# Flying       97
# Ground       35
# Poison       34
# Psychic      33
# Fighting     26
# Grass        25
# Fairy        23
# Steel        22
# Dark         20
# Dragon       18
# Ice          14
# Rock         14
# Ghost        14
# Water        14
# Fire         12
# Electric      6
# Normal        4
# Bug           3
# Name: Type 2, dtype: int64

# %%
#lets drop Nan
data1 = data

data1["Type 2"].dropna(inplace=True)
# inpplcae means data1 will change

# %%
assert 1==1 # return nothing

# %%
data["Type 2"].fillna('empty', inplace=True)
assert data["Type 2"].notnull().all()

# with asser we can check a lot

assert data.columns[1] == 'Name'

assert data.Speed.dtypes == np.float64

# %%
# pandas foundation

# building dataframes from scratch
country = ["Spain", "France"]
# population = ["11", "12","13"] # not valid array must beof same length
population = ["11","12"]
list_label = ["country", "population"]
list_col = [country, population]
zipped = list(zip(list_label, list_col))
print(zipped)
data_dict = dict(zipped)
print(data_dict)
df = pd.DataFrame(data_dict)
print(df)
# Out:
# [('country', ['Spain', 'France']), ('population', ['11', '12'])]
# {'country': ['Spain', 'France'], 'population': ['11', '12']}
#   country population
# 0   Spain         11
# 1  France         12

# %%
d = list(zip({"index":1 , "country": "india"})) # wrong way
df1 = pd.DataFrame(d)
print(df1)

index = [1]
country = ["India"]
list_label = ["index", "country"]
list_cols = [index, country]
zipped = dict(list(zip(list_label, list_cols)))
df2 = pd.DataFrame(zipped)
print(df2)
# Out:
#          0
# 0    index
# 1  country
#    index country
# 0      1   India

# %%
# adding new columns

df["capital"] = ["madrid", "Paris"]
df
# Out:
#   country population capital
# 0   Spain         11  madrid
# 1  France         12   Paris

# %%
df["income"] = 0
df
# Out:
#   country population capital  income
# 0   Spain         11  madrid       0
# 1  France         12   Paris       0

# %%
# visual analysis
# plotting all data
data1 = data.loc[:, ["Attack", "Defense","Speed"]]
data1.plot()

# %%
import matplotlib.pyplot as plt
data1.plot(subplots = True)
plt.show()

# %%
data1.plot(kind = "scatter", x="Attack", y="Defense")
plt.show()

# %%
data1.plot(kind="hist", y="Defense", bins=50,range=(0,250), density=True)

# %%
# statistical analysis
data.describe()
# Out:
#               #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.0000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   400.5000   69.258750   79.001250   73.842500   72.820000   71.902500
# std    231.0844   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.0000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    200.7500   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    400.5000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    600.2500   80.000000  100.000000   90.000000   95.000000   90.000000
# max    800.0000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %%
# indexing the time series
time_list = ["1992-03-08", "1992-04-12"]
print(type(time_list[1]))

datetime_object = pd.to_datetime(time_list)
print(type(datetime_object))
# Out:
# <class 'str'>
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
# data2 = data2.set_index("HP")
# data2
# Out:
#     #           Name Type 1  Type 2  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# HP
# 45  1      Bulbasaur  Grass  Poison      49       49       65       65   45.0
# 60  2        Ivysaur  Grass  Poison      62       63       80       80   60.0
# 80  3       Venusaur  Grass  Poison      82       83      100      100   80.0
# 80  4  Mega Venusaur  Grass  Poison     100      123      122      120   80.0
# 39  5     Charmander   Fire     NaN      52       43       60       50   65.0
#
#     Generation  Legendary
# HP
# 45           1      False
# 60           1      False
# 80           1      False
# 80           1      False
# 39           1      False

# %%
# close warning
import warnings
warnings.filterwarnings("ignore")
# In order to practice lets take head of pokemon data and add it a time list
data2 = data.head()
date_list = ["1992-01-10","1992-02-10","1992-03-10","1993-03-15","1993-03-16"]
datetime_object = pd.to_datetime(date_list)
data2["date"] = datetime_object
# lets make date as index
data2= data2.set_index("date")
data2
# Out:
#             #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# date
# 1992-01-10  1      Bulbasaur  Grass  Poison  45      49       49       65
# 1992-02-10  2        Ivysaur  Grass  Poison  60      62       63       80
# 1992-03-10  3       Venusaur  Grass  Poison  80      82       83      100
# 1993-03-15  4  Mega Venusaur  Grass  Poison  80     100      123      122
# 1993-03-16  5     Charmander   Fire     NaN  39      52       43       60
#
#             Sp. Def  Speed  Generation  Legendary
# date
# 1992-01-10       65   45.0           1      False
# 1992-02-10       80   60.0           1      False
# 1992-03-10      100   80.0           1      False
# 1993-03-15      120   80.0           1      False
# 1993-03-16       50   65.0           1      False

# %%
# RESAMPLING PANDAS TIME SERIES
'''

    Resampling: statistical method over different time intervals
        Needs string to specify frequency like "M" = month or "A" = year
    Downsampling: reduce date time rows to slower frequency like from daily to weekly
    Upsampling: increase date time rows to faster frequency like from daily to hourly
    Interpolate: Interpolate values according to different methods like ‘linear’, ‘time’ or index’
        https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.interpolate.html

'''

data2.resample("A").mean()
# Out:
#               #         HP     Attack  Defense    Sp. Atk    Sp. Def  \
# date
# 1992-12-31  2.0  61.666667  64.333333     65.0  81.666667  81.666667
# 1993-12-31  4.5  59.500000  76.000000     83.0  91.000000  85.000000
#
#                 Speed  Generation  Legendary
# date
# 1992-12-31  61.666667         1.0      False
# 1993-12-31  72.500000         1.0      False

# %%
data2.resample("M").mean()
# Out:
#               #    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# date
# 1992-01-31  1.0  45.0    49.0     49.0     65.0     65.0   45.0         1.0
# 1992-02-29  2.0  60.0    62.0     63.0     80.0     80.0   60.0         1.0
# 1992-03-31  3.0  80.0    82.0     83.0    100.0    100.0   80.0         1.0
# 1992-04-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-05-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-06-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-07-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-08-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-09-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-10-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-11-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# ...

# %%
# In real life (data is real. Not created from us like data2) we can solve this problem with interpolate
# We can interpolete from first value
# data2.resample("M").first().interpolate("linear")

# not working

# %%
# manipulating data frames with pandas
# indexing data frames

data = data.set_index('#')
data.head()
# Out:
#             Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 1      Bulbasaur  Grass  Poison  45      49       49       65       65   45.0
# 2        Ivysaur  Grass  Poison  60      62       63       80       80   60.0
# 3       Venusaur  Grass  Poison  80      82       83      100      100   80.0
# 4  Mega Venusaur  Grass  Poison  80     100      123      122      120   80.0
# 5     Charmander   Fire     NaN  39      52       43       60       50   65.0
#
#    Generation  Legendary
# #
# 1           1      False
# 2           1      False
# 3           1      False
# 4           1      False
# 5           1      False

# %%
data["HP"][1]
# Out:
# 45

# %%
data.HP[1]
# Out:
# 45

# %%
data.loc[3:4, ["HP"]]
# Out:
#    HP
# #
# 3  80
# 4  80

# %%
data[["HP","Defense"]]
# Out:
#      HP  Defense
# #
# 1    45       49
# 2    60       63
# 3    80       83
# 4    80      123
# 5    39       43
# ..   ..      ...
# 796  50      150
# 797  50      110
# 798  80       60
# 799  80       60
# 800  80      120
#
# [800 rows x 2 columns]

# %%
# slicing data frame
print(type(data["HP"]))
print(type(data[["HP"]]))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
data.loc[1:10, "HP":"Defense"]
# Out:
#     HP  Attack  Defense
# #
# 1   45      49       49
# 2   60      62       63
# 3   80      82       83
# 4   80     100      123
# 5   39      52       43
# 6   58      64       58
# 7   78      84       78
# 8   78     130      111
# 9   78     104       78
# 10  44      48       65

# %%
# reverse slicing
data.loc[10:1:-1, "HP":"Defense"]
# Out:
#     HP  Attack  Defense
# #
# 10  44      48       65
# 9   78     104       78
# 8   78     130      111
# 7   78      84       78
# 6   58      64       58
# 5   39      52       43
# 4   80     100      123
# 3   80      82       83
# 2   60      62       63
# 1   45      49       49

# %%
data.loc[1:10, "Speed":]
# Out:
#     Speed  Generation  Legendary
# #
# 1    45.0           1      False
# 2    60.0           1      False
# 3    80.0           1      False
# 4    80.0           1      False
# 5    65.0           1      False
# 6    80.0           1      False
# 7   100.0           1      False
# 8   100.0           1      False
# 9   100.0           1      False
# 10   43.0           1      False

# %%
# filtering thedata frame
boolean = data.HP > 200
data[boolean]
# Out:
#         Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 122  Chansey  Normal    NaN  250       5        5       35      105   50.0
# 262  Blissey  Normal    NaN  255      10       10       75      135   55.0
#
#      Generation  Legendary
# #
# 122           1      False
# 262           2      False

# %%
# combining filters
first_filter = data.HP >150
second_filter = data.Speed > 35
data[first_filter & second_filter]
# Out:
#           Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 122    Chansey  Normal    NaN  250       5        5       35      105   50.0
# 262    Blissey  Normal    NaN  255      10       10       75      135   55.0
# 352    Wailord   Water    NaN  170      90       45       90       45   60.0
# 656  Alomomola   Water    NaN  165      75       80       40       45   65.0
#
#      Generation  Legendary
# #
# 122           1      False
# 262           2      False
# 352           3      False
# 656           5      False

# %%
data.HP[data.Speed < 15]
# Out:
# #
# 231     20
# 360     45
# 487     50
# 496    135
# 659     44
# Name: HP, dtype: int64

# %%
# transforming data

def div(n):
    return n/2
data.HP.apply(div)
# Out:
# #
# 1      22.5
# 2      30.0
# 3      40.0
# 4      40.0
# 5      19.5
#        ...
# 796    25.0
# 797    25.0
# 798    40.0
# 799    40.0
# 800    40.0
# Name: HP, Length: 800, dtype: float64

# %%
data.HP.apply(lambda n: n/2)
# Out:
# #
# 1      22.5
# 2      30.0
# 3      40.0
# 4      40.0
# 5      19.5
#        ...
# 796    25.0
# 797    25.0
# 798    40.0
# 799    40.0
# 800    40.0
# Name: HP, Length: 800, dtype: float64

# %%
data["total_power"] = data.Attack + data.Defense
data.head()
# Out:
#             Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 1      Bulbasaur  Grass  Poison  45      49       49       65       65   45.0
# 2        Ivysaur  Grass  Poison  60      62       63       80       80   60.0
# 3       Venusaur  Grass  Poison  80      82       83      100      100   80.0
# 4  Mega Venusaur  Grass  Poison  80     100      123      122      120   80.0
# 5     Charmander   Fire     NaN  39      52       43       60       50   65.0
#
#    Generation  Legendary  total_power
# #
# 1           1      False           98
# 2           1      False          125
# 3           1      False          165
# 4           1      False          223
# 5           1      False           95

# %%
# index object and labelled data

print(data.index.name)
data.index.name = "index_name"
data.head()
# Out:
# #
#                      Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# index_name
# 1               Bulbasaur  Grass  Poison  45      49       49       65
# 2                 Ivysaur  Grass  Poison  60      62       63       80
# 3                Venusaur  Grass  Poison  80      82       83      100
# 4           Mega Venusaur  Grass  Poison  80     100      123      122
# 5              Charmander   Fire     NaN  39      52       43       60
#
#             Sp. Def  Speed  Generation  Legendary  total_power
# index_name
# 1                65   45.0           1      False           98
# 2                80   60.0           1      False          125
# 3               100   80.0           1      False          165
# 4               120   80.0           1      False          223
# 5                50   65.0           1      False           95

# %%
data3 = data.copy()
data3.index = range(100,900,1)
data3.head()
# Out:
#               Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 100      Bulbasaur  Grass  Poison  45      49       49       65       65
# 101        Ivysaur  Grass  Poison  60      62       63       80       80
# 102       Venusaur  Grass  Poison  80      82       83      100      100
# 103  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 104     Charmander   Fire     NaN  39      52       43       60       50
#
#      Speed  Generation  Legendary  total_power
# 100   45.0           1      False           98
# 101   60.0           1      False          125
# 102   80.0           1      False          165
# 103   80.0           1      False          223
# 104   65.0           1      False           95

# %%
# Hierarchical indexin
data1 = data.set_index(["Type 1", "Type 2"])
data1.head(100)
# Out:
#                         Name   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1 Type 2
# Grass  Poison      Bulbasaur   45      49       49       65       65   45.0
#        Poison        Ivysaur   60      62       63       80       80   60.0
#        Poison       Venusaur   80      82       83      100      100   80.0
#        Poison  Mega Venusaur   80     100      123      122      120   80.0
# Fire   NaN        Charmander   39      52       43       60       50   65.0
# ...                      ...  ...     ...      ...      ...      ...    ...
# Poison NaN            Grimer   80      80       50       40       50   25.0
#        NaN               Muk  105     105       75       65      100   50.0
# Water  NaN          Shellder   30      65      100       45       25   40.0
#        Ice          Cloyster   50      95      180       85       45   70.0
# Ghost  Poison         Gastly   30      35       30      100       35   80.0
#
# ...

# %%
# pivoting data frames

dic = {"treatment": ["A", "A", "B", "B"], "gender": ["F","M", "F", "M"], "response":[10,45,5,9], "age": [15,4,72,65]}
df = pd.DataFrame(dic)
df
# Out:
#   treatment gender  response  age
# 0         A      F        10   15
# 1         A      M        45    4
# 2         B      F         5   72
# 3         B      M         9   65

# %%
df.pivot(index="treatment", columns="gender", values="response")
# Out:
# gender      F   M
# treatment
# A          10  45
# B           5   9

# %%
# Stacking and unstacking dataframe
df1 = df.set_index(["treatment", "gender"])
df1
# Out:
#                   response  age
# treatment gender
# A         F             10   15
#           M             45    4
# B         F              5   72
#           M              9   65

# %%
df1.unstack(level=0)
# Out:
#           response    age
# treatment        A  B   A   B
# gender
# F               10  5  15  72
# M               45  9   4  65

# %%
df1.unstack(level=1)
# Out:
#           response     age
# gender           F   M   F   M
# treatment
# A               10  45  15   4
# B                5   9  72  65

# %%
# chanign inner and outer level index position
df2 = df1.swaplevel(0,1)
df2
# Out:
#                   response  age
# gender treatment
# F      A                10   15
# M      A                45    4
# F      B                 5   72
# M      B                 9   65

# %%
# melting data frames
df
# Out:
#   treatment gender  response  age
# 0         A      F        10   15
# 1         A      M        45    4
# 2         B      F         5   72
# 3         B      M         9   65

# %%
pd.melt(df, id_vars="treatment", value_vars=["age", "response"])
# Out:
#   treatment  variable  value
# 0         A       age     15
# 1         A       age      4
# 2         B       age     72
# 3         B       age     65
# 4         A  response     10
# 5         A  response     45
# 6         B  response      5
# 7         B  response      9

# %%
# categorical and groupby
df
# Out:
#   treatment gender  response  age
# 0         A      F        10   15
# 1         A      M        45    4
# 2         B      F         5   72
# 3         B      M         9   65

# %%
df.groupby("treatment").mean()
# Out:
#            response   age
# treatment
# A              27.5   9.5
# B               7.0  68.5

# %%
df.groupby("treatment").age.max()
# Out:
# treatment
# A    15
# B    72
# Name: age, dtype: int64

# %%
df.groupby("treatment")[["age", "response"]].min()
# Out:
#            age  response
# treatment
# A            4        10
# B           65         5

# %%
### completes the analysis done
